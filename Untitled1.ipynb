# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\python311\lib\site-packages (3.9.1)
# Requirement already satisfied: click in c:\python311\lib\site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in c:\users\hp\appdata\roaming\python\python311\site-packages (from nltk) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\python311\lib\site-packages (from nltk) (2023.6.3)
# Requirement already satisfied: tqdm in c:\python311\lib\site-packages (from nltk) (4.64.1)
# Requirement already satisfied: colorama in c:\users\hp\appdata\roaming\python\python311\site-packages (from click->nltk) (0.4.6)
# WARNING: Ignoring invalid distribution ~ (C:\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ (C:\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ (C:\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Python311\Lib\site-packages)

# %%
df=pd.read_csv("callsf0d4f5a.csv")

# %%
df['call_start_datetime'] = pd.to_datetime(df['call_start_datetime'])
df['call_end_datetime'] = pd.to_datetime(df['call_end_datetime'])
df['agent_assigned_datetime']=pd.to_datetime(df['agent_assigned_datetime'])

# %%
df['call_duration'] = (df['call_end_datetime'] - df['call_start_datetime']).dt.total_seconds() / 60

# %%
df['agent_assign_duration']=(df['agent_assigned_datetime']-df['call_start_datetime']).dt.total_seconds() / 60

# %%
df_cleaned
# Out:
#       level_0  index     call_id  customer_id  agent_id call_start_datetime  \
# 1           1     15  3313876732   6748767796    158319 2024-08-01 00:32:00
# 2           2     16  9009313118   1937394483    963118 2024-08-01 00:38:00
# 3           3     34  3107888571   6813371451    519057 2024-08-01 01:37:00
# 4           4     79  5725811355   1773534882    158319 2024-08-01 04:00:00
# 5           5     87  3494281557   3732525410    964561 2024-08-01 04:36:00
# ...       ...    ...         ...          ...       ...                 ...
# 5168     5168  71735  9012625201   4110984748    336455 2024-08-31 22:40:00
# 5170     5170  71752  3504075766   2324618148    780490 2024-08-31 22:59:00
# 5171     5171  71770  8727725650   4295424012    506130 2024-08-31 23:14:00
# 5172     5172  71785  5713760779   3306855958    102574 2024-08-31 23:29:00
# 5173     5173  71793  4035081392   4546905380    370723 2024-08-31 23:37:00
#
#      agent_assigned_datetime   call_end_datetime  \
# 1              8/1/2024 0:40 2024-08-01 01:13:00
# 2              8/1/2024 0:47 2024-08-01 01:31:00
# 3              8/1/2024 1:43 2024-08-01 02:21:00
# 4              8/1/2024 4:04 2024-08-01 04:46:00
# 5              8/1/2024 4:45 2024-08-01 05:31:00
# ...                      ...                 ...
# 5168         8/31/2024 22:49 2024-08-31 23:52:00
# 5170         8/31/2024 23:08 2024-08-31 23:47:00
# 5171         8/31/2024 23:21 2024-09-01 00:09:00
# 5172         8/31/2024 23:38 2024-09-01 01:33:00
# 5173         8/31/2024 23:45 2024-09-01 00:18:00
#
#                                         call_transcript  call_duration  \
# 1     \n\nAgent: Thank you for calling United Airlin...           41.0
# 2     \n\nAgent: Thank you for calling United Airlin...           53.0
# 3     \n\nAgent: Thank you for calling United Airlin...           44.0
# 4     \n\nAgent: Thank you for calling United Airlin...           46.0
# 5     \n\nAgent: Thank you for calling United Airlin...           55.0
# ...                                                 ...            ...
# 5168  \n\nAgent: Thank you for calling United Airlin...           72.0
# 5170  \n\nAgent: Thank you for calling United Airlin...           48.0
# 5171  \n\nAgent: Thank you for calling United Airlin...           55.0
# 5172  \n\nAgent: Thank you for calling United Airlin...          124.0
# 5173  \n\nAgent: Thank you for calling United Airlin...           41.0
#
#                                     transcript_complete  \
# 1     Thank you for calling United Airlines customer...
# 2     Thank you for calling United Airlines, my name...
# 3     Thank you for calling United Airlines customer...
# 4     Thank you for calling United Airlines, my name...
# 5     Thank you for calling United Airlines customer...
# ...                                                 ...
# 5168  Thank you for calling United Airlines, my name...
# 5170  Thank you for calling United Airlines customer...
# 5171  Thank you for calling United Airlines customer...
# 5172  Thank you for calling United Airlines, this is...
# 5173  Thank you for calling United Airlines, my name...
#
#                                      cleaned_transcript  hour day_of_week  \
# 1     thank calling united airlines customer service...     0    Thursday
# 2     thank calling united airlines name james help ...     0    Thursday
# 3     thank calling united airlines customer service...     1    Thursday
# 4     thank calling united airlines name alex may he...     4    Thursday
# 5     thank calling united airlines customer service...     4    Thursday
# ...                                                 ...   ...         ...
# 5168  thank calling united airlines name steve help ...    22    Saturday
# 5170  thank calling united airlines customer service...    22    Saturday
# 5171  thank calling united airlines customer service...    23    Saturday
# 5172  thank calling united airlines adam speaking ma...    23    Saturday
# 5173  thank calling united airlines name sarah help ...    23    Saturday
#
#      primary_call_reason
# 1               Check In
# 2            Post Flight
# 3         Mileage   Plus
# 4        Schedule Change
# 5                Seating
# ...                  ...
# 5168         Post Flight
# 5170            Checkout
# 5171   Voluntary  Cancel
# 5172         Post Flight
# 5173              IRROPS
#
# [4825 rows x 15 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Plotting the boxplot for call duration to detect outliers
plt.figure(figsize=(10, 6))
sns.boxplot(x=df['call_duration'])
plt.title("Boxplot of Call Duration (in minutes)")
plt.show()

# %%
Q1 = df['call_duration'].quantile(0.25)
Q3 = df['call_duration'].quantile(0.75)
IQR = Q3 - Q1

# Define lower and upper bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Filter out outliers
outliers = df[(df['call_duration'] >= lower_bound) & (df['call_duration'] <= upper_bound)]
df=df.drop(outliers.index,axis=0)

plt.figure(figsize=(10, 6))
sns.boxplot(x=df['call_duration'])
plt.title("Boxplot of Call Duration (in minutes)")
plt.show()

# %%
import matplotlib.pyplot as plt

# Define the bin edges for the ranges of interest (e.g., 0-10, 10-20, 20-30 minutes)
bins = range(0, int(df['call_duration'].max()) + 10, 10)

# Plot the histogram of call durations
plt.figure(figsize=(10, 6))
plt.hist(df['call_duration'], bins=bins, edgecolor='black', alpha=0.7)

# Add labels and title
plt.xlabel('Call Duration (minutes)')
plt.ylabel('Number of Clients')
plt.title('Distribution of Call Durations by Clients')

# Display the plot
plt.show()

# %%
df
# Out:
#       level_0  index     call_id  customer_id  agent_id call_start_datetime  \
# 0           0     11  7732610078   4029953261    488324 2024-08-01 00:23:00
# 1           1     15  3313876732   6748767796    158319 2024-08-01 00:32:00
# 2           2     16  9009313118   1937394483    963118 2024-08-01 00:38:00
# 3           3     34  3107888571   6813371451    519057 2024-08-01 01:37:00
# 4           4     79  5725811355   1773534882    158319 2024-08-01 04:00:00
# ...       ...    ...         ...          ...       ...                 ...
# 5169     5169  71736   727694488   5500822696    859203 2024-08-31 22:43:00
# 5170     5170  71752  3504075766   2324618148    780490 2024-08-31 22:59:00
# 5171     5171  71770  8727725650   4295424012    506130 2024-08-31 23:14:00
# 5172     5172  71785  5713760779   3306855958    102574 2024-08-31 23:29:00
# 5173     5173  71793  4035081392   4546905380    370723 2024-08-31 23:37:00
#
#      agent_assigned_datetime   call_end_datetime  \
# 0        2024-08-01 00:34:00 2024-08-01 01:32:00
# 1        2024-08-01 00:40:00 2024-08-01 01:13:00
# 2        2024-08-01 00:47:00 2024-08-01 01:31:00
# 3        2024-08-01 01:43:00 2024-08-01 02:21:00
# 4        2024-08-01 04:04:00 2024-08-01 04:46:00
# ...                      ...                 ...
# 5169     2024-08-31 22:51:00 2024-08-31 23:54:00
# 5170     2024-08-31 23:08:00 2024-08-31 23:47:00
# 5171     2024-08-31 23:21:00 2024-09-01 00:09:00
# 5172     2024-08-31 23:38:00 2024-09-01 01:33:00
# 5173     2024-08-31 23:45:00 2024-09-01 00:18:00
#
#                                         call_transcript  call_duration  \
# 0     \n\nAgent: Thank you for calling United Airlin...           69.0
# 1     \n\nAgent: Thank you for calling United Airlin...           41.0
# 2     \n\nAgent: Thank you for calling United Airlin...           53.0
# 3     \n\nAgent: Thank you for calling United Airlin...           44.0
# 4     \n\nAgent: Thank you for calling United Airlin...           46.0
# ...                                                 ...            ...
# 5169  \n\nAgent: Thank you for calling United Airlin...           71.0
# 5170  \n\nAgent: Thank you for calling United Airlin...           48.0
# 5171  \n\nAgent: Thank you for calling United Airlin...           55.0
# 5172  \n\nAgent: Thank you for calling United Airlin...          124.0
# 5173  \n\nAgent: Thank you for calling United Airlin...           41.0
#
#                                     transcript_complete  \
# 0     Thank you for calling United Airlines customer...
# 1     Thank you for calling United Airlines customer...
# 2     Thank you for calling United Airlines, my name...
# 3     Thank you for calling United Airlines customer...
# 4     Thank you for calling United Airlines, my name...
# ...                                                 ...
# 5169  Thank you for calling United Airlines, my name...
# 5170  Thank you for calling United Airlines customer...
# 5171  Thank you for calling United Airlines customer...
# 5172  Thank you for calling United Airlines, this is...
# 5173  Thank you for calling United Airlines, my name...
#
#                                      cleaned_transcript  hour day_of_week  \
# 0     thank calling united airlines customer service...     0    Thursday
# 1     thank calling united airlines customer service...     0    Thursday
# 2     thank calling united airlines name james help ...     0    Thursday
# 3     thank calling united airlines customer service...     1    Thursday
# 4     thank calling united airlines name alex may he...     4    Thursday
# ...                                                 ...   ...         ...
# 5169  thank calling united airlines name michael may...    22    Saturday
# 5170  thank calling united airlines customer service...    22    Saturday
# 5171  thank calling united airlines customer service...    23    Saturday
# 5172  thank calling united airlines adam speaking ma...    23    Saturday
# 5173  thank calling united airlines name sarah help ...    23    Saturday
#
#       agent_assign_duration
# 0                     -11.0
# 1                      -8.0
# 2                      -9.0
# 3                      -6.0
# 4                      -4.0
# ...                     ...
# 5169                   -8.0
# 5170                   -9.0
# 5171                   -7.0
# 5172                   -9.0
# 5173                   -8.0
#
# [5174 rows x 15 columns]

# %%
import matplotlib.pyplot as plt

# Define the bin edges for the ranges of interest (e.g., 0-10, 10-20, 20-30 minutes)
bins = range(0, int(df['agent_assign_duration'].max()) + 1, 1)

# Plot the histogram of call durations
plt.figure(figsize=(10, 6))
plt.hist(df['agent_assign_duration'], bins=bins, edgecolor='black', alpha=0.7)

# Add labels and title
plt.xlabel('Call Duration (minutes)')
plt.ylabel('Number of Clients')
plt.title('distribution of waiting time of queue for various clients')

# Display the plot
plt.show()

# %%
df2=pd.read_csv("customers2afd6ea.csv")

# %%
df3=pd.read_csv("reason18315ff.csv")

# %%
Average_Handle_Time = df.groupby('agent_id')['call_duration'].mean().reset_index()

# %%
Average_Speed_Time = df.groupby('agent_id')['agent_assign_duration'].mean().reset_index()

# %%
Average_Handle_Time
# Out:
#      agent_id  call_duration
# 0      102574     124.000000
# 1      103651      53.740741
# 2      106000      53.625000
# 3      107876      45.000000
# 4      112609      76.000000
# ..        ...            ...
# 347    981776      55.960000
# 348    981779      55.687500
# 349    982131      52.500000
# 350    992521      65.400000
# 351    993862      53.136364
#
# [352 rows x 2 columns]

# %%
Average_Speed_Time
# Out:
#      agent_id  agent_assign_duration
# 0      102574               9.000000
# 1      103651               7.407407
# 2      106000               7.500000
# 3      107876              11.000000
# 4      112609               4.000000
# ..        ...                    ...
# 347    981776               7.880000
# 348    981779               8.312500
# 349    982131               6.954545
# 350    992521               9.000000
# 351    993862               7.727273
#
# [352 rows x 2 columns]

# %%
from matplotlib import pyplot as plt
Average_Handle_Time['call_duration'].plot(kind='line', figsize=(8, 4), title='Average Handle Time')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
from matplotlib import pyplot as plt
Average_Speed_Time['agent_assign_duration'].plot(kind='line', figsize=(8, 4), title='Average Handle Time')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
df.reset_index(inplace=True)
df
# Out:
#       level_0  index     call_id  customer_id  agent_id call_start_datetime  \
# 0           0     11  7732610078   4029953261    488324 2024-08-01 00:23:00
# 1           1     15  3313876732   6748767796    158319 2024-08-01 00:32:00
# 2           2     16  9009313118   1937394483    963118 2024-08-01 00:38:00
# 3           3     34  3107888571   6813371451    519057 2024-08-01 01:37:00
# 4           4     79  5725811355   1773534882    158319 2024-08-01 04:00:00
# ...       ...    ...         ...          ...       ...                 ...
# 5169     5169  71736   727694488   5500822696    859203 2024-08-31 22:43:00
# 5170     5170  71752  3504075766   2324618148    780490 2024-08-31 22:59:00
# 5171     5171  71770  8727725650   4295424012    506130 2024-08-31 23:14:00
# 5172     5172  71785  5713760779   3306855958    102574 2024-08-31 23:29:00
# 5173     5173  71793  4035081392   4546905380    370723 2024-08-31 23:37:00
#
#      agent_assigned_datetime   call_end_datetime  \
# 0              8/1/2024 0:34 2024-08-01 01:32:00
# 1              8/1/2024 0:40 2024-08-01 01:13:00
# 2              8/1/2024 0:47 2024-08-01 01:31:00
# 3              8/1/2024 1:43 2024-08-01 02:21:00
# 4              8/1/2024 4:04 2024-08-01 04:46:00
# ...                      ...                 ...
# 5169         8/31/2024 22:51 2024-08-31 23:54:00
# 5170         8/31/2024 23:08 2024-08-31 23:47:00
# 5171         8/31/2024 23:21 2024-09-01 00:09:00
# 5172         8/31/2024 23:38 2024-09-01 01:33:00
# 5173         8/31/2024 23:45 2024-09-01 00:18:00
#
#                                         call_transcript  call_duration
# 0     \n\nAgent: Thank you for calling United Airlin...           69.0
# 1     \n\nAgent: Thank you for calling United Airlin...           41.0
# 2     \n\nAgent: Thank you for calling United Airlin...           53.0
# 3     \n\nAgent: Thank you for calling United Airlin...           44.0
# 4     \n\nAgent: Thank you for calling United Airlin...           46.0
# ...                                                 ...            ...
# 5169  \n\nAgent: Thank you for calling United Airlin...           71.0
# 5170  \n\nAgent: Thank you for calling United Airlin...           48.0
# 5171  \n\nAgent: Thank you for calling United Airlin...           55.0
# 5172  \n\nAgent: Thank you for calling United Airlin...          124.0
# 5173  \n\nAgent: Thank you for calling United Airlin...           41.0
#
# [5174 rows x 10 columns]

# %%
df["call_transcript"].apply(lambda x:len(str(x).split()))[0]
# Out:
# 384

# %%
def clean_transcript(text):
    text = text.replace('Agent:', '').replace('Customer:', '')
    return text.strip()

# Apply the function to the 'transcript' column
df['transcript_complete'] = df['call_transcript'].apply(clean_transcript)

# Display the cleaned transcripts
df[['call_transcript', 'transcript_complete']].head()
# Out:
#                                      call_transcript  \
# 0  \n\nAgent: Thank you for calling United Airlin...
# 1  \n\nAgent: Thank you for calling United Airlin...
# 2  \n\nAgent: Thank you for calling United Airlin...
# 3  \n\nAgent: Thank you for calling United Airlin...
# 4  \n\nAgent: Thank you for calling United Airlin...
#
#                                  transcript_complete
# 0  Thank you for calling United Airlines customer...
# 1  Thank you for calling United Airlines customer...
# 2  Thank you for calling United Airlines, my name...
# 3  Thank you for calling United Airlines customer...
# 4  Thank you for calling United Airlines, my name...

# %%
import nltk
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer
import re

# Download stopwords from nltk
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))

# Function to clean the transcripts
def preprocess_transcript(text):
    # Remove special characters, numbers, and lower the text
    text = re.sub(r'[^a-zA-Z]', ' ', text.lower())
    
    # Tokenize and remove stopwords
    tokens = text.split()
    tokens = [word for word in tokens if word not in stop_words]
    
    return ' '.join(tokens)

# Apply the preprocessing function to the 'transcript' column
df['cleaned_transcript'] = df['transcript_complete'].apply(preprocess_transcript)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
df['cleaned_transcript']
# Out:
# 0       thank calling united airlines customer service...
# 1       thank calling united airlines customer service...
# 2       thank calling united airlines name james help ...
# 3       thank calling united airlines customer service...
# 4       thank calling united airlines name alex may he...
#                               ...
# 5169    thank calling united airlines name michael may...
# 5170    thank calling united airlines customer service...
# 5171    thank calling united airlines customer service...
# 5172    thank calling united airlines adam speaking ma...
# 5173    thank calling united airlines name sarah help ...
# Name: cleaned_transcript, Length: 5174, dtype: object

# %%
df['hour'] = df['call_start_datetime'].dt.hour
df['day_of_week'] = df['call_start_datetime'].dt.day_name()

# Plot average call duration by hour
plt.figure(figsize=(10, 6))
sns.lineplot(x='hour', y='call_duration', data=df)
plt.title('Average Call Duration by Hour')
plt.show()

# Plot average call duration by day of the week
plt.figure(figsize=(6, 20))
sns.barplot(x='day_of_week', y='call_duration', data=df)
plt.title('Average Call Duration by Day of the Week')
plt.show()

# %%
df_merge = df.merge(df3[['call_id', 'primary_call_reason']], on='call_id', how='left')

# %%
df_merge
# Out:
#       level_0  index     call_id  customer_id  agent_id call_start_datetime  \
# 0           0     11  7732610078   4029953261    488324 2024-08-01 00:23:00
# 1           1     15  3313876732   6748767796    158319 2024-08-01 00:32:00
# 2           2     16  9009313118   1937394483    963118 2024-08-01 00:38:00
# 3           3     34  3107888571   6813371451    519057 2024-08-01 01:37:00
# 4           4     79  5725811355   1773534882    158319 2024-08-01 04:00:00
# ...       ...    ...         ...          ...       ...                 ...
# 5169     5169  71736   727694488   5500822696    859203 2024-08-31 22:43:00
# 5170     5170  71752  3504075766   2324618148    780490 2024-08-31 22:59:00
# 5171     5171  71770  8727725650   4295424012    506130 2024-08-31 23:14:00
# 5172     5172  71785  5713760779   3306855958    102574 2024-08-31 23:29:00
# 5173     5173  71793  4035081392   4546905380    370723 2024-08-31 23:37:00
#
#      agent_assigned_datetime   call_end_datetime  \
# 0        2024-08-01 00:34:00 2024-08-01 01:32:00
# 1        2024-08-01 00:40:00 2024-08-01 01:13:00
# 2        2024-08-01 00:47:00 2024-08-01 01:31:00
# 3        2024-08-01 01:43:00 2024-08-01 02:21:00
# 4        2024-08-01 04:04:00 2024-08-01 04:46:00
# ...                      ...                 ...
# 5169     2024-08-31 22:51:00 2024-08-31 23:54:00
# 5170     2024-08-31 23:08:00 2024-08-31 23:47:00
# 5171     2024-08-31 23:21:00 2024-09-01 00:09:00
# 5172     2024-08-31 23:38:00 2024-09-01 01:33:00
# 5173     2024-08-31 23:45:00 2024-09-01 00:18:00
#
#                                         call_transcript  call_duration  \
# 0     \n\nAgent: Thank you for calling United Airlin...           69.0
# 1     \n\nAgent: Thank you for calling United Airlin...           41.0
# 2     \n\nAgent: Thank you for calling United Airlin...           53.0
# 3     \n\nAgent: Thank you for calling United Airlin...           44.0
# 4     \n\nAgent: Thank you for calling United Airlin...           46.0
# ...                                                 ...            ...
# 5169  \n\nAgent: Thank you for calling United Airlin...           71.0
# 5170  \n\nAgent: Thank you for calling United Airlin...           48.0
# 5171  \n\nAgent: Thank you for calling United Airlin...           55.0
# 5172  \n\nAgent: Thank you for calling United Airlin...          124.0
# 5173  \n\nAgent: Thank you for calling United Airlin...           41.0
#
#                                     transcript_complete  \
# 0     Thank you for calling United Airlines customer...
# 1     Thank you for calling United Airlines customer...
# 2     Thank you for calling United Airlines, my name...
# 3     Thank you for calling United Airlines customer...
# 4     Thank you for calling United Airlines, my name...
# ...                                                 ...
# 5169  Thank you for calling United Airlines, my name...
# 5170  Thank you for calling United Airlines customer...
# 5171  Thank you for calling United Airlines customer...
# 5172  Thank you for calling United Airlines, this is...
# 5173  Thank you for calling United Airlines, my name...
#
#                                      cleaned_transcript  hour day_of_week  \
# 0     thank calling united airlines customer service...     0    Thursday
# 1     thank calling united airlines customer service...     0    Thursday
# 2     thank calling united airlines name james help ...     0    Thursday
# 3     thank calling united airlines customer service...     1    Thursday
# 4     thank calling united airlines name alex may he...     4    Thursday
# ...                                                 ...   ...         ...
# 5169  thank calling united airlines name michael may...    22    Saturday
# 5170  thank calling united airlines customer service...    22    Saturday
# 5171  thank calling united airlines customer service...    23    Saturday
# 5172  thank calling united airlines adam speaking ma...    23    Saturday
# 5173  thank calling united airlines name sarah help ...    23    Saturday
#
#       agent_assign_duration primary_call_reason
# 0                      11.0                 NaN
# 1                       8.0            Check In
# 2                       9.0         Post Flight
# 3                       6.0      Mileage   Plus
# 4                       4.0     Schedule Change
# ...                     ...                 ...
# 5169                    8.0                 NaN
# 5170                    9.0            Checkout
# 5171                    7.0   Voluntary  Cancel
# 5172                    9.0         Post Flight
# 5173                    8.0              IRROPS
#
# [5174 rows x 16 columns]

# %%
df_cleaned=df_merge.dropna(subset=["primary_call_reason"])
df_cleaned
# Out:
#       level_0  index     call_id  customer_id  agent_id call_start_datetime  \
# 1           1     15  3313876732   6748767796    158319 2024-08-01 00:32:00
# 2           2     16  9009313118   1937394483    963118 2024-08-01 00:38:00
# 3           3     34  3107888571   6813371451    519057 2024-08-01 01:37:00
# 4           4     79  5725811355   1773534882    158319 2024-08-01 04:00:00
# 5           5     87  3494281557   3732525410    964561 2024-08-01 04:36:00
# ...       ...    ...         ...          ...       ...                 ...
# 5168     5168  71735  9012625201   4110984748    336455 2024-08-31 22:40:00
# 5170     5170  71752  3504075766   2324618148    780490 2024-08-31 22:59:00
# 5171     5171  71770  8727725650   4295424012    506130 2024-08-31 23:14:00
# 5172     5172  71785  5713760779   3306855958    102574 2024-08-31 23:29:00
# 5173     5173  71793  4035081392   4546905380    370723 2024-08-31 23:37:00
#
#      agent_assigned_datetime   call_end_datetime  \
# 1        2024-08-01 00:40:00 2024-08-01 01:13:00
# 2        2024-08-01 00:47:00 2024-08-01 01:31:00
# 3        2024-08-01 01:43:00 2024-08-01 02:21:00
# 4        2024-08-01 04:04:00 2024-08-01 04:46:00
# 5        2024-08-01 04:45:00 2024-08-01 05:31:00
# ...                      ...                 ...
# 5168     2024-08-31 22:49:00 2024-08-31 23:52:00
# 5170     2024-08-31 23:08:00 2024-08-31 23:47:00
# 5171     2024-08-31 23:21:00 2024-09-01 00:09:00
# 5172     2024-08-31 23:38:00 2024-09-01 01:33:00
# 5173     2024-08-31 23:45:00 2024-09-01 00:18:00
#
#                                         call_transcript  call_duration  \
# 1     \n\nAgent: Thank you for calling United Airlin...           41.0
# 2     \n\nAgent: Thank you for calling United Airlin...           53.0
# 3     \n\nAgent: Thank you for calling United Airlin...           44.0
# 4     \n\nAgent: Thank you for calling United Airlin...           46.0
# 5     \n\nAgent: Thank you for calling United Airlin...           55.0
# ...                                                 ...            ...
# 5168  \n\nAgent: Thank you for calling United Airlin...           72.0
# 5170  \n\nAgent: Thank you for calling United Airlin...           48.0
# 5171  \n\nAgent: Thank you for calling United Airlin...           55.0
# 5172  \n\nAgent: Thank you for calling United Airlin...          124.0
# 5173  \n\nAgent: Thank you for calling United Airlin...           41.0
#
#                                     transcript_complete  \
# 1     Thank you for calling United Airlines customer...
# 2     Thank you for calling United Airlines, my name...
# 3     Thank you for calling United Airlines customer...
# 4     Thank you for calling United Airlines, my name...
# 5     Thank you for calling United Airlines customer...
# ...                                                 ...
# 5168  Thank you for calling United Airlines, my name...
# 5170  Thank you for calling United Airlines customer...
# 5171  Thank you for calling United Airlines customer...
# 5172  Thank you for calling United Airlines, this is...
# 5173  Thank you for calling United Airlines, my name...
#
#                                      cleaned_transcript  hour day_of_week  \
# 1     thank calling united airlines customer service...     0    Thursday
# 2     thank calling united airlines name james help ...     0    Thursday
# 3     thank calling united airlines customer service...     1    Thursday
# 4     thank calling united airlines name alex may he...     4    Thursday
# 5     thank calling united airlines customer service...     4    Thursday
# ...                                                 ...   ...         ...
# 5168  thank calling united airlines name steve help ...    22    Saturday
# 5170  thank calling united airlines customer service...    22    Saturday
# 5171  thank calling united airlines customer service...    23    Saturday
# 5172  thank calling united airlines adam speaking ma...    23    Saturday
# 5173  thank calling united airlines name sarah help ...    23    Saturday
#
#       agent_assign_duration primary_call_reason
# 1                       8.0            Check In
# 2                       9.0         Post Flight
# 3                       6.0      Mileage   Plus
# 4                       4.0     Schedule Change
# 5                       9.0             Seating
# ...                     ...                 ...
# 5168                    9.0         Post Flight
# 5170                    9.0            Checkout
# 5171                    7.0   Voluntary  Cancel
# 5172                    9.0         Post Flight
# 5173                    8.0              IRROPS
#
# [4825 rows x 16 columns]

# %%
import matplotlib.pyplot as plt

# Group the data by 'primary_call_reason' and sum the call durations
reason_duration = df_cleaned.groupby('primary_call_reason')['call_duration'].sum()

# Sort by maximum duration to get the top reasons
reason_duration_sorted = reason_duration.sort_values(ascending=False)

# Plot a pie chart of the top reasons for call duration
plt.figure(figsize=(10, 7))
plt.pie(reason_duration_sorted, labels=reason_duration_sorted.index, autopct='%1.1f%%', startangle=90)
plt.title('Reasons for Maximum Call Duration')
plt.axis('equal')  # Ensures the pie chart is circular
plt.show()

# %%
df_cleaned
# Out:
#       level_0  index     call_id  customer_id  agent_id call_start_datetime  \
# 1           1     15  3313876732   6748767796    158319 2024-08-01 00:32:00
# 2           2     16  9009313118   1937394483    963118 2024-08-01 00:38:00
# 3           3     34  3107888571   6813371451    519057 2024-08-01 01:37:00
# 4           4     79  5725811355   1773534882    158319 2024-08-01 04:00:00
# 5           5     87  3494281557   3732525410    964561 2024-08-01 04:36:00
# ...       ...    ...         ...          ...       ...                 ...
# 5168     5168  71735  9012625201   4110984748    336455 2024-08-31 22:40:00
# 5170     5170  71752  3504075766   2324618148    780490 2024-08-31 22:59:00
# 5171     5171  71770  8727725650   4295424012    506130 2024-08-31 23:14:00
# 5172     5172  71785  5713760779   3306855958    102574 2024-08-31 23:29:00
# 5173     5173  71793  4035081392   4546905380    370723 2024-08-31 23:37:00
#
#      agent_assigned_datetime   call_end_datetime  \
# 1              8/1/2024 0:40 2024-08-01 01:13:00
# 2              8/1/2024 0:47 2024-08-01 01:31:00
# 3              8/1/2024 1:43 2024-08-01 02:21:00
# 4              8/1/2024 4:04 2024-08-01 04:46:00
# 5              8/1/2024 4:45 2024-08-01 05:31:00
# ...                      ...                 ...
# 5168         8/31/2024 22:49 2024-08-31 23:52:00
# 5170         8/31/2024 23:08 2024-08-31 23:47:00
# 5171         8/31/2024 23:21 2024-09-01 00:09:00
# 5172         8/31/2024 23:38 2024-09-01 01:33:00
# 5173         8/31/2024 23:45 2024-09-01 00:18:00
#
#                                         call_transcript  call_duration  \
# 1     \n\nAgent: Thank you for calling United Airlin...           41.0
# 2     \n\nAgent: Thank you for calling United Airlin...           53.0
# 3     \n\nAgent: Thank you for calling United Airlin...           44.0
# 4     \n\nAgent: Thank you for calling United Airlin...           46.0
# 5     \n\nAgent: Thank you for calling United Airlin...           55.0
# ...                                                 ...            ...
# 5168  \n\nAgent: Thank you for calling United Airlin...           72.0
# 5170  \n\nAgent: Thank you for calling United Airlin...           48.0
# 5171  \n\nAgent: Thank you for calling United Airlin...           55.0
# 5172  \n\nAgent: Thank you for calling United Airlin...          124.0
# 5173  \n\nAgent: Thank you for calling United Airlin...           41.0
#
#                                     transcript_complete  \
# 1     Thank you for calling United Airlines customer...
# 2     Thank you for calling United Airlines, my name...
# 3     Thank you for calling United Airlines customer...
# 4     Thank you for calling United Airlines, my name...
# 5     Thank you for calling United Airlines customer...
# ...                                                 ...
# 5168  Thank you for calling United Airlines, my name...
# 5170  Thank you for calling United Airlines customer...
# 5171  Thank you for calling United Airlines customer...
# 5172  Thank you for calling United Airlines, this is...
# 5173  Thank you for calling United Airlines, my name...
#
#                                      cleaned_transcript  hour day_of_week  \
# 1     thank calling united airlines customer service...     0    Thursday
# 2     thank calling united airlines name james help ...     0    Thursday
# 3     thank calling united airlines customer service...     1    Thursday
# 4     thank calling united airlines name alex may he...     4    Thursday
# 5     thank calling united airlines customer service...     4    Thursday
# ...                                                 ...   ...         ...
# 5168  thank calling united airlines name steve help ...    22    Saturday
# 5170  thank calling united airlines customer service...    22    Saturday
# 5171  thank calling united airlines customer service...    23    Saturday
# 5172  thank calling united airlines adam speaking ma...    23    Saturday
# 5173  thank calling united airlines name sarah help ...    23    Saturday
#
#      primary_call_reason
# 1               Check In
# 2            Post Flight
# 3         Mileage   Plus
# 4        Schedule Change
# 5                Seating
# ...                  ...
# 5168         Post Flight
# 5170            Checkout
# 5171   Voluntary  Cancel
# 5172         Post Flight
# 5173              IRROPS
#
# [4825 rows x 15 columns]

# %%
df_cleaned['primary_call_reason'] = df_cleaned['primary_call_reason'].str.replace(' ', '', regex=True).str.replace('-', '', regex=True).str.lower()
grouped_reasons = df_cleaned.groupby('primary_call_reason')

# Display the size of each group (number of transcripts per reason)
call_reason_counts = grouped_reasons.size().sort_values(ascending=False)
print(call_reason_counts)
# Out:
# primary_call_reason
# irrops                 1056
# mileageplus             745
# postflight              649
# voluntarychange         615
# checkout                348
# communications          300
# seating                 191
# productsandservices     184
# voluntarycancel         157
# etc                     146
# upgrade                 113
# checkin                 111
# booking                  56
# baggage                  42
# products&services        29
# schedulechange           28
# digitalsupport           21
# travelerupdates          19
# othertopics               7
# unaccompaniedminor        4
# disability                4
# dtype: int64
# C:\Users\HP\AppData\Local\Temp\ipykernel_34700\1410308057.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['primary_call_reason'] = df_cleaned['primary_call_reason'].str.replace(' ', '', regex=True).str.replace('-', '', regex=True).str.lower()

# %%
avg_duration_per_reason = grouped_reasons['call_duration'].mean().sort_values(ascending=False)

# Calculate total call duration for each call reason
total_duration_per_reason = grouped_reasons['call_duration'].sum().sort_values(ascending=False)

# Display the top reasons taking the longest time
print("Average Call Duration per Reason:")
print(avg_duration_per_reason)

print("\nTotal Call Duration per Reason:")
print(total_duration_per_reason)
# Out:
# Average Call Duration per Reason:
# primary_call_reason
# checkin                63.927928
# voluntarycancel        57.375796
# postflight             57.064715
# products&services      57.000000
# mileageplus            56.357047
# booking                56.214286
# etc                    55.719178
# checkout               55.520115
# communications         55.220000
# upgrade                54.619469
# productsandservices    54.548913
# schedulechange         53.607143
# irrops                 53.542614
# seating                52.073298
# voluntarychange        51.801626
# unaccompaniedminor     51.500000
# travelerupdates        51.052632
# baggage                49.500000
# digitalsupport         48.095238
# othertopics            47.142857
# disability             46.250000
# Name: call_duration, dtype: float64
#
# Total Call Duration per Reason:
# primary_call_reason
# irrops                 56541.0
# mileageplus            41986.0
# postflight             37035.0
# voluntarychange        31858.0
# checkout               19321.0
# communications         16566.0
# productsandservices    10037.0
# seating                 9946.0
# voluntarycancel         9008.0
# etc                     8135.0
# checkin                 7096.0
# upgrade                 6172.0
# booking                 3148.0
# baggage                 2079.0
# products&services       1653.0
# schedulechange          1501.0
# digitalsupport          1010.0
# travelerupdates          970.0
# othertopics              330.0
# unaccompaniedminor       206.0
# disability               185.0
# Name: call_duration, dtype: float64

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# Vectorize the transcript data (convert words into numerical features)
tfidf_vectorizer = TfidfVectorizer(stop_words='english', max_features=1000)
X_tfidf = tfidf_vectorizer.fit_transform(df_cleaned['call_transcript'].fillna(''))

# Get feature names (words)
feature_names = tfidf_vectorizer.get_feature_names_out()

# Convert the TF-IDF matrix to a DataFrame
df_tfidf = pd.DataFrame(X_tfidf.toarray(), columns=feature_names)

# Get the most frequent words across all transcripts
top_words = df_tfidf.sum().sort_values(ascending=False).head(50)
print(top_words)
# Out:
# flight          879.175431
# agent           790.090615
# customer        789.249241
# change          489.135788
# let             444.800522
# help            291.825386
# like            283.546636
# thank           270.321053
# fee             252.921472
# united          245.049472
# typing          238.586145
# calling         233.023890
# work            227.822626
# time            226.796044
# okay            224.858839
# need            222.072476
# day             219.255283
# just            214.838896
# chicago         201.878074
# really          199.047464
# know            196.578023
# yeah            196.516313
# thanks          193.910791
# new             192.669106
# ll              190.760399
# reservation     189.579563
# travel          187.395328
# make            184.125037
# date            178.350293
# earlier         178.183560
# booked          176.959671
# today           176.455002
# la              171.175115
# looks           170.878444
# look            162.665376
# ve              162.631804
# confirmation    160.107210
# better          159.429871
# check           157.410047
# good            157.260721
# does            156.276332
# problem         155.264730
# delay           154.104017
# wednesday       153.999264
# number          151.813595
# meeting         150.830309
# monday          149.447613
# understand      147.532733
# ahead           143.824374
# return          140.293980
# dtype: float64
